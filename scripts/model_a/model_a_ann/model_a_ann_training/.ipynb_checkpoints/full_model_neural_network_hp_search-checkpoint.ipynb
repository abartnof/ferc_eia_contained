# %% [markdown]
# https://docs.ray.io/en/latest/tune/examples/tune_mnist_keras.html

# %%
from keras import models, layers, regularizers, optimizers, callbacks, utils
from keras.metrics import BinaryAccuracy, AUC, BinaryCrossentropy
from tensorflow.keras.backend import clear_session

import pandas as pd
import numpy as np
import os

from tensorflow import convert_to_tensor
utils.set_random_seed(1)
# from sklearn.metrics import confusion_matrix, accuracy_score, precision_score

# import matplotlib.pyplot as plt

# %%
from ray import train, tune
from ray.tune.search.optuna import OptunaSearch
# from ray.tune.schedulers import ASHAScheduler
from ray.tune.search import ConcurrencyLimiter

# %%
fn_train_x = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_a/train/train_x.parquet'
fn_train_y = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_a/train/train_y.parquet'

fn_test_x = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_a/train/test_x.parquet'
fn_test_y = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_a/train/test_y.parquet'

# %%
TrainX = pd.read_parquet(fn_train_x)
TrainX
# Out:
#           dist_plant_name_lv  dist_plant_name_lcs  dist_utility_name_lv  \
# 0                  -1.846154            -1.344828              0.096774
# 1                  -1.846154            -1.034483              0.193548
# 2                  -0.923077            -0.310345              0.000000
# 3                  -1.730769            -1.344828              0.000000
# 4                  -1.038462            -0.310345              0.000000
# ...                      ...                  ...                   ...
# 10193089           -1.269231            -1.241379             -0.967742
# 10193090           -1.038462            -0.827586             -0.870968
# 10193091           -1.615385            -1.241379             -0.774194
# 10193092           -0.461538            -0.620690             -1.064516
# 10193093           -2.076923            -2.172414             -2.516129
#
#           dist_utility_name_lcs  dist_plant_name_refined_lv  \
# 0                      0.000000                       -1.35
# 1                      0.648649                       -1.35
# 2                      0.891892                       -1.50
# 3                      0.162162                       -1.35
# 4                      0.405405                       -1.05
# ...                         ...                         ...
# 10193089              -0.486486                       -1.95
# 10193090              -0.324324                       -1.20
# 10193091              -0.324324                       -1.80
# 10193092              -0.648649                       -1.80
# 10193093              -2.594595                       -1.80
#
#           dist_plant_name_refined_lcs  dist_utility_name_refined_lv  \
# 0                           -1.730769                      0.692308
# 1                           -1.730769                      0.923077
# 2                           -1.153846                      0.923077
# 3                           -1.153846                      0.692308
# 4                           -0.461538                      0.576923
# ...                               ...                           ...
# 10193089                    -1.961538                     -0.461538
# 10193090                    -1.384615                     -0.692308
# 10193091                    -1.730769                     -0.346154
# 10193092                    -1.500000                     -0.115385
# 10193093                    -2.076923                     -1.384615
#
#           dist_utility_name_refined_lcs  does_plant_name_ferc_contain_digits  \
# 0                              0.636364                                  3.0
# 1                              0.363636                                  3.0
# 2                              1.181818                                  3.0
# 3                              0.181818                                  3.0
# 4                              0.636364                                  3.0
# ...                                 ...                                  ...
# 10193089                      -0.727273                                 -3.0
# 10193090                      -0.818182                                 -3.0
# 10193091                      -0.272727                                 -3.0
# 10193092                      -0.727273                                 -3.0
# 10193093                      -1.727273                                 -3.0
#
#           does_plant_name_eia_contain_digits  ...  \
# 0                                       -3.0  ...
# 1                                       -3.0  ...
# 2                                       -3.0  ...
# 3                                       -3.0  ...
# 4                                       -3.0  ...
# ...                                      ...  ...
# 10193089                                -3.0  ...
# 10193090                                -3.0  ...
# 10193091                                -3.0  ...
# 10193092                                -3.0  ...
# 10193093                                -3.0  ...
#
#           prime_mover_code_eia_X.Missing.  plant_part_eia_plant  \
# 0                                    -3.0                  -3.0
# 1                                    -3.0                   3.0
# 2                                    -3.0                  -3.0
# 3                                    -3.0                  -3.0
# 4                                    -3.0                  -3.0
# ...                                   ...                   ...
# 10193089                             -3.0                  -3.0
# 10193090                             -3.0                  -3.0
# 10193091                             -3.0                  -3.0
# 10193092                             -3.0                   3.0
# 10193093                             -3.0                  -3.0
#
#           plant_part_eia_plant_ferc_acct  plant_part_eia_plant_gen  \
# 0                                   -3.0                       3.0
# 1                                   -3.0                      -3.0
# 2                                   -3.0                      -3.0
# 3                                   -3.0                       3.0
# 4                                   -3.0                       3.0
# ...                                  ...                       ...
# 10193089                            -3.0                       3.0
# 10193090                            -3.0                       3.0
# 10193091                            -3.0                      -3.0
# 10193092                            -3.0                      -3.0
# 10193093                            -3.0                      -3.0
#
#           plant_part_eia_plant_match_ferc1  \
# 0                                     -3.0
# 1                                     -3.0
# 2                                     -3.0
# 3                                     -3.0
# 4                                     -3.0
# ...                                    ...
# 10193089                              -3.0
# 10193090                              -3.0
# 10193091                              -3.0
# 10193092                              -3.0
# 10193093                              -3.0
#
#           plant_part_eia_plant_operating_year  \
# 0                                        -3.0
# 1                                        -3.0
# 2                                        -3.0
# 3                                        -3.0
# 4                                        -3.0
# ...                                       ...
# 10193089                                 -3.0
# 10193090                                 -3.0
# 10193091                                  3.0
# 10193092                                 -3.0
# 10193093                                 -3.0
#
#           plant_part_eia_plant_prime_fuel  plant_part_eia_plant_prime_mover  \
# 0                                    -3.0                              -3.0
# 1                                    -3.0                              -3.0
# 2                                    -3.0                               3.0
# 3                                    -3.0                              -3.0
# 4                                    -3.0                              -3.0
# ...                                   ...                               ...
# 10193089                             -3.0                              -3.0
# 10193090                             -3.0                              -3.0
# 10193091                             -3.0                              -3.0
# 10193092                             -3.0                              -3.0
# 10193093                             -3.0                               3.0
#
#           plant_part_eia_plant_technology  plant_part_eia_plant_unit
# 0                                    -3.0                       -3.0
# 1                                    -3.0                       -3.0
# 2                                    -3.0                       -3.0
# 3                                    -3.0                       -3.0
# 4                                    -3.0                       -3.0
# ...                                   ...                        ...
# 10193089                             -3.0                       -3.0
# 10193090                             -3.0                       -3.0
# 10193091                             -3.0                       -3.0
# 10193092                             -3.0                       -3.0
# 10193093                             -3.0                       -3.0
#
# [10193094 rows x 57 columns]

# %%
def fit_mod(space):
    # Load data
    os.chdir('/Users/andrewbartnof/Documents/rmi/rematch_ferc_eia1/clean_data/')
    TrainX = convert_to_tensor(pd.read_parquet('train_x.parquet'))
    train_y = pd.read_parquet('train_y.parquet').pop('is_match')
    ValX = convert_to_tensor(pd.read_parquet('validation_x.parquet'))
    val_y = pd.read_parquet('validation_y.parquet').pop('is_match')

    # Establish class weights
    pos = train_y.sum()
    neg = (train_y == 0).sum()
    total = len(train_y)
    weight_for_0 = (1 / neg) * (total / 2.0)
    weight_for_1 = (1 / pos) * (total / 2.0)
    class_weight = {0: weight_for_0, 1: weight_for_1}

    # Fit model
    clear_session()
    model = models.Sequential()
    model.add(layers.Dropout(rate=space["dropout_1"]))
    model.add(layers.Dense(units=int(space["relu_1"]), activation='relu'))    
    model.add(layers.Dropout(rate=space["dropout_2"]))
    model.add(layers.Dense(units=int(space["relu_2"]), activation='relu'))   
    model.add(layers.Dense(1, activation='sigmoid'))
        
    model.compile(optimizer=optimizers.SGD(),
        loss='binary_crossentropy',
        metrics=[BinaryCrossentropy(), AUC()]
        )
        
    history = model.fit(
        TrainX, train_y, epochs=500, batch_size=128,  # hard-coded here
        validation_data=(ValX, val_y), 
        class_weight=class_weight,
        callbacks=callbacks.EarlyStopping(patience=5, start_from_epoch=10),
        verbose=0
    )

    best_binary_crossentropy = np.min(history.history['val_binary_crossentropy'][10:])
    best_auc = np.max(history.history['val_auc'][10:])
    train.report(
        {
            "binary_crossentropy": best_binary_crossentropy,
            "auc": best_auc
        }
    )

# %%
search_alg = OptunaSearch(metric="binary_crossentropy", mode="min")
search_alg = ConcurrencyLimiter(search_alg, max_concurrent=1)

space = {
    'relu_1': tune.randint(1, 57),
    'relu_2': tune.randint(1, 57),
    'dropout_1': tune.uniform(0.0001, 1),
    'dropout_2': tune.uniform(0.0001, 1),
    # 'objective':'binary',
    'metrics':['binary_logloss', 'auc']
}

# %%
tuner = tune.Tuner(
    fit_mod,
    tune_config=tune.TuneConfig(
        # scheduler=asha_scheduler,
        search_alg=search_alg,
        num_samples=500
    ),
    param_space=space,
    run_config=train.RunConfig(
        storage_path=hp_dir, 
        name="full_model_neural_network_hp_search"
    )
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-09-26 19:29:06</td></tr>
# <tr><td>Running for: </td><td>00:00:31.53        </td></tr>
# <tr><td>Memory:      </td><td>6.4/8.0 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 2<br><table>
# <thead>
# <tr><th>Trial name      </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                                                                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>fit_mod_29bc5f86</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-09-26_19-22-34_336301_41696/artifacts/2024-09-26_19-28-34/full_neural_network_raytune_hp_search/driver_artifacts/fit_mod_29bc5f86_1_dropout_1=0.3849,dropout_2=0.7292,metrics=binary_logloss_auc,objective=binary,relu_1=54,relu_2=46_2024-09-26_19-28-34/error.txt</td></tr>
# <tr><td>fit_mod_91ff1745</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-09-26_19-22-34_336301_41696/artifacts/2024-09-26_19-28-34/full_neural_network_raytune_hp_search/driver_artifacts/fit_mod_91ff1745_2_dropout_1=0.6157,dropout_2=0.5117,metrics=binary_logloss_auc,objective=binary,relu_1=7,relu_2=25_2024-09-26_19-28-45/error.txt </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name      </th><th>status  </th><th>loc            </th><th style="text-align: right;">  dropout_1</th><th style="text-align: right;">  dropout_2</th><th style="text-align: right;">  relu_1</th><th style="text-align: right;">  relu_2</th></tr>
# </thead>
# <tbody>
# <tr><td>fit_mod_acd89ee4</td><td>RUNNING </td><td>127.0.0.1:41788</td><td style="text-align: right;">   0.513131</td><td style="text-align: right;">   0.487093</td><td style="text-align: right;">      33</td><td style="text-align: right;">      32</td></tr>
# <tr><td>fit_mod_29bc5f86</td><td>ERROR   </td><td>127.0.0.1:41773</td><td style="text-align: right;">   0.384946</td><td style="text-align: right;">   0.729172</td><td style="text-align: right;">      54</td><td style="text-align: right;">      46</td></tr>
# <tr><td>fit_mod_91ff1745</td><td>ERROR   </td><td>127.0.0.1:41783</td><td style="text-align: right;">   0.615677</td><td style="text-align: right;">   0.511665</td><td style="text-align: right;">       7</td><td style="text-align: right;">      25</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-09-26 19:28:45,420	ERROR tune_controller.py:1331 -- Trial task failed for trial fit_mod_29bc5f86
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/worker.py", line 2656, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=41773, ip=127.0.0.1, actor_id=03fec9cac4c691a2a6dc8f9a01000000, repr=fit_mod)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 248, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/var/folders/zh/p6wj0vfs3qq684w4b1m0_tvr0000gn/T/ipykernel_41696/694137482.py", line 20, in fit_mod
# NameError: name 'dropout_1' is not defined
# 2024-09-26 19:28:56,270	ERROR tune_controller.py:1331 -- Trial task failed for trial fit_mod_91ff1745
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/worker.py", line 2656, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=41783, ip=127.0.0.1, actor_id=d3c2ad7e59cc6235cad5f54d01000000, repr=fit_mod)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 248, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/var/folders/zh/p6wj0vfs3qq684w4b1m0_tvr0000gn/T/ipykernel_41696/694137482.py", line 20, in fit_mod
# NameError: name 'dropout_1' is not defined
# 2024-09-26 19:29:06,296	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-09-26 19:29:06,302	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/andrewbartnof/Documents/rmi/rematch_ferc_eia1/clean_data/hyperparameters/full_neural_network_raytune_hp_search' in 0.0045s.
# 2024-09-26 19:29:06,680	ERROR worker.py:409 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::ImplicitFunc.train() (pid=41788, ip=127.0.0.1, actor_id=4a46587d5817bb10c821092601000000, repr=fit_mod)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/lib/python3.12/site-packages/ray/tune/trainable/function_trainable.py", line 248, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/var/folders/zh/p6wj0vfs3qq684w4b1m0_tvr0000gn/T/ipykernel_41696/694137482.py", line 20, in fit_mod
# NameError: name 'dropout_1' is not defined
# 2024-09-26 19:29:06,683	ERROR tune.py:1037 -- Trials did not complete: [fit_mod_29bc5f86, fit_mod_91ff1745]
# 2024-09-26 19:29:06,684	INFO tune.py:1041 -- Total run time: 31.92 seconds (31.52 seconds for the tuning loop).
# 2024-09-26 19:29:06,684	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/Users/andrewbartnof/Documents/rmi/rematch_ferc_eia1/clean_data/hyperparameters/full_neural_network_raytune_hp_search", trainable=...)

# %%
# !jupyter nbconvert --to script full_model_neural_network_hp_search.ipynb
# Out:
# [NbConvertApp] Converting notebook full_model_neural_network_hp_search.ipynb to script
# [NbConvertApp] Writing 3396 bytes to full_model_neural_network_hp_search.py
