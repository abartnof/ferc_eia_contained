# %% [markdown]
# # Perform an initial search for optimal hyperparameters
#
# __author__: Andrew Bartnof
#
# __copyright__: Copyright 2025, Rocky Mountain Institute
#
# __credits__: Alex Engel, Andrew Bartnof

# %%
import lightgbm as lgb
import numpy as np
import pandas as pd
import dask
import os 

from ray import train, tune
from ray.tune.search.optuna import OptunaSearch
# from ray.tune.schedulers import ASHAScheduler
from ray.tune.search import ConcurrencyLimiter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# from optuna.samplers import TPESampler

# %%
data_dir = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker'
dir_working_model_b_training = os.path.join(data_dir, 'working_data/model_b/model_b_training')
dir_working_model_b_training
# Out:
# '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_b/model_b_training'

# %%
fn_x = os.path.join(dir_working_model_b_training, 'x.parquet')
fn_y = os.path.join(dir_working_model_b_training, 'y.parquet')
fn_id = os.path.join(dir_working_model_b_training, 'id.parquet')

dir_hyperparameters = dir_working_model_b_training
fn_out = os.path.join(dir_working_model_b_training, 'gb_ray_tune/model_b_ann_hp_search.csv')

# dir_hyperparameters = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_b/train'
# fn_out = '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_b/train/gb_ray_tune/grid_search.csv'

# %%
def np_cleaning(X):
    X = np.clip(X, a_min=-3, a_max=3)
    X = np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0)
    return X

# %%
def fit_mod(space):
    
    # Read data
    X = pd.read_parquet(fn_x)
    Y = pd.read_parquet(fn_y)
    ID = pd.read_parquet(fn_id)
    
    # Split data into testing and training
    fold_array = np.arange(5)
    fold_variable = np.random.choice(fold_array, size=1)[0]
    
    is_train_mask = (ID['fold'] != fold_variable).values
    XTrain = X.loc[is_train_mask]
    XTest = X.loc[~is_train_mask]
    
    # Scale numeric values
    standard_scaler = StandardScaler()
    
    standard_scaler.fit(XTrain)
    XTrain = standard_scaler.transform(XTrain)
    XTest  = standard_scaler.transform(XTest)
    
    XTrain = np_cleaning(XTrain)
    XTest  = np_cleaning(XTest)
    
    # Package in training and testing objects
    train_set = lgb.Dataset(XTrain, Y.loc[is_train_mask])
    test_set  = lgb.Dataset(XTest,  Y.loc[~is_train_mask])

    # Model
    evals={}
    gbm = lgb.train(
        space,
        train_set,
        valid_sets=[test_set],
        callbacks = [lgb.record_evaluation(evals)]
    )
    binary_logloss = evals['valid_0']['binary_logloss'][-1]
    auc = evals['valid_0']['auc'][-1]
    
    train.report(
        {
            "binary_logloss": binary_logloss,
            "auc": auc
        }
    )

# %%
space = {
    # 'num_iterations': tune.randint(1, 1000),
    'verbose':-1,
    'num_trees': tune.randint(1, 1000),
    'learning_rate': tune.uniform(0.0001, 0.75),
    'min_data_in_leaf': tune.randint(1, 200),
    'objective':'binary', 
    # 'early_stopping_round':2,
    'early_stopping_round':-1,
    'metrics':['binary_logloss', 'auc']
    }

# %%
# asha = ASHAScheduler(metric='binary_logloss', mode='min')

search_alg = OptunaSearch(metric="binary_logloss", mode="min")
search_alg = ConcurrencyLimiter(search_alg, max_concurrent=1)

# %%
tuner = tune.Tuner(
    fit_mod,
    tune_config=tune.TuneConfig(
        # scheduler=asha,
        num_samples=250,
        search_alg=search_alg,
    ),
    param_space=space,
    run_config=train.RunConfig(
        storage_path=dir_hyperparameters, 
        name="gb_ray_tune"
    )
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-02-26 22:20:52</td></tr>
# <tr><td>Running for: </td><td>10:51:47.66        </td></tr>
# <tr><td>Memory:      </td><td>2.7/8.0 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name      </th><th>status    </th><th>loc            </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  min_data_in_leaf</th><th style="text-align: right;">  num_trees</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  binary_logloss</th><th style="text-align: right;">      auc</th></tr>
# </thead>
# <tbody>
# <tr><td>fit_mod_b9fa7f76</td><td>TERMINATED</td><td>127.0.0.1:59338</td><td style="text-align: right;">    0.561238   </td><td style="text-align: right;">               171</td><td style="text-align: right;">        692</td><td style="text-align: right;">     1</td><td style="text-align: right;">        176.955 </td><td style="text-align: right;">     8.56241    </td><td style="text-align: right;">0.605504 </td></tr>
# <tr><td>fit_mod_accfe384</td><td>TERMINATED</td><td>127.0.0.1:59428</td><td style="text-align: right;">    0.707286   </td><td style="text-align: right;">               155</td><td style="text-align: right;">        427</td><td style="text-align: right;">     1</td><td style="text-align: right;">        102.146 </td><td style="text-align: right;">     0.0351214  </td><td style="text-align: right;">0.373414 </td></tr>
# <tr><td>fit_mod_6ad59ba2</td><td>TERMINATED</td><td>127.0.0.1:59445</td><td style="text-align: right;">    0.373086   </td><td style="text-align: right;">                28</td><td style="text-align: right;">        195</td><td style="text-align: right;">     1</td><td style="text-align: right;">         86.6072</td><td style="text-align: right;">     0.0564925  </td><td style="text-align: right;">0.372775 </td></tr>
# <tr><td>fit_mod_7770997a</td><td>TERMINATED</td><td>127.0.0.1:59453</td><td style="text-align: right;">    0.648973   </td><td style="text-align: right;">                60</td><td style="text-align: right;">        760</td><td style="text-align: right;">     1</td><td style="text-align: right;">        132.519 </td><td style="text-align: right;">     0.0441865  </td><td style="text-align: right;">0.943841 </td></tr>
# <tr><td>fit_mod_222ddd2d</td><td>TERMINATED</td><td>127.0.0.1:59459</td><td style="text-align: right;">    0.556329   </td><td style="text-align: right;">                28</td><td style="text-align: right;">        978</td><td style="text-align: right;">     1</td><td style="text-align: right;">        179.546 </td><td style="text-align: right;">     0.0851383  </td><td style="text-align: right;">0.7657   </td></tr>
# <tr><td>fit_mod_50e7273e</td><td>TERMINATED</td><td>127.0.0.1:59528</td><td style="text-align: right;">    0.226599   </td><td style="text-align: right;">                78</td><td style="text-align: right;">        149</td><td style="text-align: right;">     1</td><td style="text-align: right;">         71.1514</td><td style="text-align: right;">     3.91601    </td><td style="text-align: right;">0.0751492</td></tr>
# <tr><td>fit_mod_bd2e5220</td><td>TERMINATED</td><td>127.0.0.1:59536</td><td style="text-align: right;">    0.368673   </td><td style="text-align: right;">                78</td><td style="text-align: right;">        283</td><td style="text-align: right;">     1</td><td style="text-align: right;">         81.7855</td><td style="text-align: right;">     0.0378754  </td><td style="text-align: right;">0.806072 </td></tr>
/opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65741)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=65767) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65767)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=65843) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65843)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=65845) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65845)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=65884) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65884)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=65955) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65955)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=65999) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=65999)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66012) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66012)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66042) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66042)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66106) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66106)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66136) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66136)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66156) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66156)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66205) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66205)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66261) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66261)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66288) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66288)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66322) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66322)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66362) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66362)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66389) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66389)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66416) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66416)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66540) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66540)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66581) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66581)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66611) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66611)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66630) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66630)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66693) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66693)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66717) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66717)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66763) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66763)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66811) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66811)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66844) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66844)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66868) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66868)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66908) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66908)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=66930) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=66930)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67025) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67025)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67064) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67064)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67098) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67098)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67159) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67159)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67234) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67234)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67254) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67254)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67272) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67272)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67314) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67314)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67341) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67341)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67364) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67364)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67386) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67386)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67408) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67408)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67442) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67442)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67505) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67505)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67542) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67542)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67577) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67577)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67640) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67640)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67666) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67666)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67670) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67670)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67725) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67725)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=67939) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=67939)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=68003) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=68003)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=68032) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=68032)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=68085) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=68085)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=68100) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=68100)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (fit_mod pid=68122) /opt/miniconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_trees` in params. Will use it instead of argument
# (fit_mod pid=68122)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# 2025-02-26 22:20:52,953	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Volumes/Extreme SSD/rematch_eia_ferc1_docker/working_data/model_b/model_b_training/gb_ray_tune' in 0.2210s.
# 2025-02-26 22:20:52,984	INFO tune.py:1041 -- Total run time: 39107.71 seconds (39107.43 seconds for the tuning loop).

# %%
Grid = results.get_dataframe().copy()

# %%
Grid.index.name = 'order'
RankedGrid = Grid.sort_values(['binary_logloss', 'auc'], ascending=[True, False]).reset_index()
RankedGrid.index.name = 'rank'
RankedGrid.to_csv(fn_out)

# %%
RankedGrid.sort_values('binary_logloss').head(10)[['binary_logloss', 'auc', 'config/num_trees', 'config/learning_rate', 'config/min_data_in_leaf']]
# Out:
#       binary_logloss       auc  config/num_trees  config/learning_rate  \
# rank
# 0           0.000194  0.999964               899              0.014190
# 1           0.000197  0.999961               837              0.012723
# 2           0.000199  0.999992               888              0.010747
# 3           0.000200  0.999958               894              0.010668
# 4           0.000201  0.999992               856              0.012409
# 5           0.000203  0.999964               889              0.012008
# 6           0.000208  0.999990               936              0.015645
# 7           0.000209  0.999958               770              0.015908
# 8           0.000209  0.999992               853              0.011632
# 9           0.000219  0.999880               897              0.012356
#
#       config/min_data_in_leaf
# rank
# 0                         152
# 1                         149
# 2                         153
# 3                         153
# 4                         159
# 5                         152
# 6                         151
# 7                         141
# 8                         146
# 9                         151

# %%
# experiment_path = "/Users/andrewbartnof/Documents/rmi/rematch_ferc_eia1/clean_data/model_full_gradient_boost/ray_tune/gb_ray_tune"
# restored_tuner = tune.Tuner.restore(experiment_path, trainable=fit_mod)

# %%
# fn_results = '/Users/andrewbartnof/Documents/rmi/rematch_ferc_eia1/clean_data/model_full_gradient_boost/ray_tune/ray_tune_dataframe.csv'
# restored_tuner.get_results().get_dataframe().to_csv(fn_results)

# %%
# !jupyter nbconvert --to script model_b_gbm_hyperparameter_search.ipynb
# Out:
# [NbConvertApp] Converting notebook model_b_gbm_hyperparameter_search.ipynb to script
# [NbConvertApp] Writing 4399 bytes to model_b_gbm_hyperparameter_search.py
